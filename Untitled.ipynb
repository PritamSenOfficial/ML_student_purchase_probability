# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#   student_country  days_on_platform  minutes_watched  courses_started  \
# 0              EG               126              0.2                1
# 1              PT               126             18.6                1
# 2              PK               176            466.2                5
# 3              NG               129             44.9                1
# 4              PK               123             17.7                1
#
#    practice_exams_started  practice_exams_passed  minutes_spent_on_exams  \
# 0                       1                      0                   10.00
# 1                       1                      0                   16.00
# 2                       2                      1                   13.59
# 3                       1                      1                    5.18
# 4                       1                      0                   16.00
#
#    purchased
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['student_country_encoded'] = label_encoder.fit_transform(df['student_country'])

# %%
df1 = pd.get_dummies(df, columns=['student_country'], prefix='country')

# %%
df.columns
# Out:
# Index(['student_country', 'days_on_platform', 'minutes_watched',
#        'courses_started', 'practice_exams_started', 'practice_exams_passed',
#        'minutes_spent_on_exams', 'purchased', 'student_country_encoded'],
#       dtype='object')

# %%
df1[5:]
# Out:
#        days_on_platform  minutes_watched  courses_started  \
# 5                   236           2235.3               11
# 6                   129             43.4                1
# 7                   118             20.3                1
# 8                   117            151.0                2
# 9                   118             23.4                1
# ...                 ...              ...              ...
# 17656                 0              0.8                1
# 17657                 0              0.1                1
# 17658                 0              7.8                1
# 17659                 0             10.4                1
# 17660                 0              0.1                1
#
#        practice_exams_started  practice_exams_passed  minutes_spent_on_exams  \
# 5                          25                     14                  121.23
# 6                           2                      2                    6.82
# ...

# %%
df
# Out:
#       student_country  days_on_platform  minutes_watched  courses_started  \
# 0                  EG               126              0.2                1
# 1                  PT               126             18.6                1
# 2                  PK               176            466.2                5
# 3                  NG               129             44.9                1
# 4                  PK               123             17.7                1
# ...               ...               ...              ...              ...
# 17656              EG                 0              0.8                1
# 17657              IN                 0              0.1                1
# 17658              CM                 0              7.8                1
# 17659              CA                 0             10.4                1
# 17660              SA                 0              0.1                1
#
#        practice_exams_started  practice_exams_passed  minutes_spent_on_exams  \
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have already calculated the correlation matrix
corr_matrix = df.corr()

# Create a heatmap using Matplotlib's imshow
plt.figure(figsize=(10, 8))
plt.imshow(corr_matrix, cmap='coolwarm', interpolation='none', aspect='auto')
plt.colorbar()
plt.xticks(np.arange(len(corr_matrix.columns)), corr_matrix.columns, rotation='vertical')
plt.yticks(np.arange(len(corr_matrix.columns)), corr_matrix.columns)
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\Pritam\AppData\Local\Temp\ipykernel_5428\730814213.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %%
x = ['minutes_watched', 'practice_exams_started', 'practice_exams_passed','minutes_spent_on_exams']
r = pd.DataFrame(df[x].corr())
r
# Out:
#                         minutes_watched  practice_exams_started  \
# minutes_watched                1.000000                0.560874
# practice_exams_started         0.560874                1.000000
# practice_exams_passed          0.588862                0.914286
# minutes_spent_on_exams         0.587103                0.838670
#
#                         practice_exams_passed  minutes_spent_on_exams
# minutes_watched                      0.588862                0.587103
# practice_exams_started               0.914286                0.838670
# practice_exams_passed                1.000000                0.799302
# minutes_spent_on_exams               0.799302                1.000000
